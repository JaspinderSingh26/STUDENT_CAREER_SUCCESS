# %%
import pandas as pd;

# %%
df = pd.read_csv("C:\\Users\\ASUS\\Downloads\\student_career_success_dataset.csv")

# %%
df.shape
# Out:
# (50000, 29)

# %%
df.isnull().sum()
# Out:
# Student_ID               0
# Age                      0
# Gender                   0
# University_Year          0
# Major                    0
# Attendance_Percentage    0
# Study_Hours_Per_Week     0
# CGPA                     0
# Academic_Performance     0
# Programming_Skill        0
# Projects_Completed       0
# Certifications           0
# Hackathons               0
# GitHub_Profile           0
# Internships              0
# Leadership_Experience    0
# LinkedIn_Profile         0
# Resume_Score             0
# Communication_Skills     0
# Teamwork                 0
# Problem_Solving          0
# English_Proficiency      0
# Interview_Score          0
# Employability_Score      0
# Placement_Status         0
# Company_Tier             0
# Career_Field             0
# Placement_Mode           0
# Starting_Salary_USD      0
# dtype: int64

# %%
df.describe()
# Out:
#                 Age  Attendance_Percentage  Study_Hours_Per_Week  \
# count  50000.000000           50000.000000           50000.00000
# mean      21.262900              81.409640              21.52816
# std        2.041163               9.709519               6.97481
# min       18.000000              50.000000               5.00000
# 25%       20.000000              75.000000              17.00000
# 50%       21.000000              82.000000              21.00000
# 75%       22.000000              88.000000              26.00000
# max       30.000000             100.000000              45.00000
#
#                CGPA  Programming_Skill  Projects_Completed  Certifications  \
# count  50000.000000       50000.000000        50000.000000    50000.000000
# mean       3.106043           7.137160            8.620560        1.715660
# std        0.290351           1.507194            2.505408        1.368301
# min        2.000000           1.000000            0.000000        0.000000
# 25%        2.910000           6.000000            7.000000        1.000000
# 50%        3.110000           7.000000            9.000000        2.000000
# 75%        3.310000           8.000000           10.000000        3.000000
# max        4.000000          10.000000           15.000000        8.000000
#
#          Hackathons   Internships  Resume_Score  Communication_Skills  \
# count  50000.000000  50000.000000  50000.000000          50000.000000
# mean       3.093940      4.048880     96.045740              8.435780
# std        1.660774      1.005719      7.331565              1.387543
# min        0.000000      0.000000     44.000000              3.000000
# 25%        2.000000      3.000000     95.000000              7.000000
# 50%        3.000000      4.000000    100.000000              9.000000
# 75%        4.000000      5.000000    100.000000             10.000000
# max       10.000000      5.000000    100.000000             10.000000
#
#            Teamwork  Problem_Solving  Interview_Score  Employability_Score  \
# count  50000.000000     50000.000000     50000.000000         50000.000000
# mean       7.006200         7.175060        77.515400           213.991394
# std        1.606802         1.674428        12.579382            26.824224
# min        2.000000         1.000000        17.000000            82.300000
# 25%        6.000000         6.000000        70.000000           197.350000
# 50%        7.000000         7.000000        78.000000           217.250000
# 75%        8.000000         8.000000        87.000000           233.600000
# max       10.000000        10.000000       100.000000           279.050000
#
#        Starting_Salary_USD
# count         50000.000000
# mean          68988.167480
# std           38480.607679
# min               0.000000
# 25%           65229.250000
# 50%           83044.500000
# 75%           96486.250000
# max          110000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Student_ID             50000 non-null  object
#  1   Age                    50000 non-null  int64
#  2   Gender                 50000 non-null  object
#  3   University_Year        50000 non-null  object
#  4   Major                  50000 non-null  object
#  5   Attendance_Percentage  50000 non-null  int64
#  6   Study_Hours_Per_Week   50000 non-null  int64
#  7   CGPA                   50000 non-null  float64
#  8   Academic_Performance   50000 non-null  object
#  9   Programming_Skill      50000 non-null  int64
#  10  Projects_Completed     50000 non-null  int64
#  11  Certifications         50000 non-null  int64
#  12  Hackathons             50000 non-null  int64
#  13  GitHub_Profile         50000 non-null  object
#  14  Internships            50000 non-null  int64
#  15  Leadership_Experience  50000 non-null  object
#  16  LinkedIn_Profile       50000 non-null  object
#  17  Resume_Score           50000 non-null  int64
#  18  Communication_Skills   50000 non-null  int64
#  19  Teamwork               50000 non-null  int64
#  20  Problem_Solving        50000 non-null  int64
#  21  English_Proficiency    50000 non-null  object
#  22  Interview_Score        50000 non-null  int64
#  23  Employability_Score    50000 non-null  float64
#  24  Placement_Status       50000 non-null  object
#  25  Company_Tier           50000 non-null  object
#  26  Career_Field           50000 non-null  object
#  27  Placement_Mode         50000 non-null  object
#  28  Starting_Salary_USD    50000 non-null  int64
# dtypes: float64(2), int64(14), object(13)
# memory usage: 11.1+ MB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Student_ID               0
# Age                      0
# Gender                   0
# University_Year          0
# Major                    0
# Attendance_Percentage    0
# Study_Hours_Per_Week     0
# CGPA                     0
# Academic_Performance     0
# Programming_Skill        0
# Projects_Completed       0
# Certifications           0
# Hackathons               0
# GitHub_Profile           0
# Internships              0
# Leadership_Experience    0
# LinkedIn_Profile         0
# Resume_Score             0
# Communication_Skills     0
# Teamwork                 0
# Problem_Solving          0
# English_Proficiency      0
# Interview_Score          0
# Employability_Score      0
# Placement_Status         0
# Company_Tier             0
# Career_Field             0
# Placement_Mode           0
# Starting_Salary_USD      0
# dtype: int64

# %%
total_students = len(df)
print(total_students)
# Out:
# 50000

# %%
for i in ("Age", "CGPA", "Interview_Score"):
    df[i] = df[i].fillna(df[i].mean())

# %%
for i in ("Gender", "Placement_Mode"):
    df[i] = df[i].fillna(df[i].mode()[0])

# %%
df["Gender"].unique()
# Out:
# array(['Male', 'Female', 'Other'], dtype=object)

# %%
df["Major"].unique()
# Out:
# array(['Computer Science', 'Information Technology',
#        'Software Engineering', 'Artificial Intelligence',
#        'Business Analytics', 'Data Science', 'Cybersecurity',
#        'Electrical Engineering'], dtype=object)

# %%
df["Major"].dtype
# Out:
# dtype('O')

# %%
df["Placement_Mode"].unique()
# Out:
# array(['Campus Placement', 'Not Applicable', 'Internship Conversion',
#        'Off-Campus', 'Referral'], dtype=object)

# %%
df["Placement_Mode"] = df["Placement_Mode"].str.lower()

# %%
for i in ("Gender", "Placement_Mode", "University_Year", "Company_Tier", "Placement_Status"):
    df[i]
    print(df[i].unique())
    print()
# Out:
# ['Male' 'Female' 'Other']
#
# ['campus placement' 'not applicable' 'internship conversion' 'off-campus'
#  'referral']
#
# ['Sophomore' 'Freshman' 'Senior' 'Junior']
#
# ['Tier 1' 'No Company' 'Tier 2' 'Tier 3']
#
# ['Placed' 'Not Placed']

# %%
df["Student_ID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
q1 = df["CGPA"].quantile(0.25)
q3 = df["CGPA"].quantile(0.75)

iqr = q3 - q1

lower = q1 - 1.5*iqr
upper = q3 + 1.5*iqr

print(q1)
print(q3)
print(iqr)
print(lower)
print(upper)
# Out:
# 2.91
# 3.31
# 0.3999999999999999
# 2.3100000000000005
# 3.91

# %%
outliers = df[(df["CGPA"] < lower) | (df["CGPA"] > upper)]

# %%
outliers["CGPA"].value_counts()
# Out:
# CGPA
# 4.00    30
# 2.27    22
# 2.28    19
# 2.31    17
# 2.29    17
# 3.92    14
# 3.93    13
# 2.23    12
# 2.30    11
# 3.95    11
# 3.94     9
# 3.96     8
# 3.98     8
# 2.26     7
# 3.99     7
# 2.24     7
# 3.97     6
# 2.25     6
# 2.22     5
# 2.21     5
# 2.14     4
# 2.19     4
# 2.12     3
# 2.18     3
# 2.17     3
# 2.08     3
# 2.20     2
# 2.06     2
# 2.03     1
# 2.02     1
# 2.15     1
# 2.13     1
# 2.04     1
# 2.16     1
# 2.10     1
# 2.00     1
# 2.09     1
# Name: count, dtype: int64

# %%
len(outliers)
# Out:
# 267

# %%
outliers[["Student_ID", "Major", "CGPA", "Starting_Salary_USD", "Employability_Score", "Placement_Status"]]
# Out:
#       Student_ID                    Major  CGPA  Starting_Salary_USD  \
# 573     ST000574            Cybersecurity  2.12                    0
# 1112    ST001113   Electrical Engineering  2.22                    0
# 1213    ST001214   Information Technology  2.30                68513
# 1259    ST001260     Software Engineering  3.96                71301
# 1415    ST001416         Computer Science  3.96                    0
# ...          ...                      ...   ...                  ...
# 48688   ST048689         Computer Science  2.23                63305
# 48789   ST048790  Artificial Intelligence  2.27                47134
# 48869   ST048870         Computer Science  4.00                87503
# 49027   ST049028             Data Science  2.31                76518
# 49525   ST049526            Cybersecurity  2.31                56387
#
#        Employability_Score Placement_Status
# 573                 145.20       Not Placed
# 1112                161.70       Not Placed
# 1213                171.50           Placed
# 1259                262.40           Placed
# 1415                262.90       Not Placed
# ...                    ...              ...
# 48688               151.85           Placed
# 48789               156.25           Placed
# 48869               267.00           Placed
# 49027               190.05           Placed
# 49525               166.25           Placed
#
# [267 rows x 6 columns]

# %%
q1 = df["Starting_Salary_USD"].quantile(0.25)
q3 = df["Starting_Salary_USD"].quantile(0.75)

iqr = q3 - q1

lower = q1 - 1.5*iqr
upper = q3 + 1.5*iqr

print(q1)
print(q3)
print(iqr)
print(lower)
print(upper)
# Out:
# 65229.25
# 96486.25
# 31257.0
# 18343.75
# 143371.75

# %%
outlier_Price = df[(df["Starting_Salary_USD"] < lower) | (df["Starting_Salary_USD"] > upper)]

# %%
outlier_Price["Starting_Salary_USD"].value_counts()
# Out:
# Starting_Salary_USD
# 0    10960
# Name: count, dtype: int64

# %%
len(outlier_Price)
# Out:
# 10960

# %%
outlier_Price[["Student_ID", "Major", "CGPA", "Starting_Salary_USD", "Employability_Score", "Placement_Status"]].head(15)
# Out:
#    Student_ID                    Major  CGPA  Starting_Salary_USD  \
# 1    ST000002         Computer Science  2.53                    0
# 3    ST000004   Information Technology  2.80                    0
# 7    ST000008       Business Analytics  2.87                    0
# 9    ST000010   Information Technology  2.85                    0
# 11   ST000012         Computer Science  3.32                    0
# 13   ST000014             Data Science  2.94                    0
# 27   ST000028       Business Analytics  3.23                    0
# 28   ST000029         Computer Science  3.29                    0
# 36   ST000037             Data Science  2.81                    0
# 41   ST000042         Computer Science  2.97                    0
# 45   ST000046            Cybersecurity  2.99                    0
# 47   ST000048  Artificial Intelligence  3.02                    0
# 52   ST000053   Electrical Engineering  2.90                    0
# 56   ST000057  Artificial Intelligence  3.51                    0
# 57   ST000058             Data Science  3.27                    0
#
#     Employability_Score Placement_Status
# 1                157.45       Not Placed
# 3                171.50       Not Placed
# 7                160.35       Not Placed
# 9                166.65       Not Placed
# 11               239.30       Not Placed
# 13               215.60       Not Placed
# 27               179.35       Not Placed
# 28               210.65       Not Placed
# 36               189.55       Not Placed
# 41               214.05       Not Placed
# 45               191.95       Not Placed
# 47               206.20       Not Placed
# 52               180.50       Not Placed
# 56               243.65       Not Placed
# 57               210.05       Not Placed

# %%
# Q1. How many unique student_id are there in the dataset?
df["Student_ID"].nunique()
# Out:
# 50000

# %%
# Which major has the highest number of students
print(df.groupby("Major").size().sort_values(ascending=False).head(1))
# Out:
# Major
# Computer Science    12407
# dtype: int64

# %%
# How many students were placed using each Placement Mode?
df.groupby("Placement_Mode").size()
# Out:
# Placement_Mode
# campus placement         19619
# internship conversion     7674
# not applicable           10960
# off-campus                7817
# referral                  3930
# dtype: int64

# %%
# Calculate the Average Starting Salary (across all students)
avg_salary = df["Starting_Salary_USD"].sum() / df["Student_ID"].nunique()
print(avg_salary)
# Out:
# 68988.16748

# %%
# Find the Top 5 majors by total starting salary
df.groupby("Major")["Starting_Salary_USD"].sum().sort_values(ascending=False).head()
# Out:
# Major
# Computer Science           871751000
# Artificial Intelligence    582043660
# Software Engineering       578970437
# Data Science               435035221
# Cybersecurity              352217142
# Name: Starting_Salary_USD, dtype: int64

# %%
# Which university year generates the highest total starting salary
df.groupby("University_Year")["Starting_Salary_USD"].sum().sort_values(ascending=False).head(1)
# Out:
# University_Year
# Junior    1020771171
# Name: Starting_Salary_USD, dtype: int64

# %%
# Which major has the highest average Employability Score
df.groupby("Major")["Employability_Score"].mean().sort_values(ascending=False).head(1)
# Out:
# Major
# Artificial Intelligence    226.633205
# Name: Employability_Score, dtype: float64

# %%
# For each Major and Gender combination, calculate the total starting salary
df.groupby(["Major", "Gender"])["Starting_Salary_USD"].sum()
# Out:
# Major                    Gender
# Artificial Intelligence  Female    283577807
#                          Male      287702490
#                          Other      10763363
# Business Analytics       Female    101310818
#                          Male       94176441
#                          Other       3955873
# Computer Science         Female    428552378
#                          Male      425665048
#                          Other      17533574
# Cybersecurity            Female    175772589
#                          Male      171572206
#                          Other       4872347
# Data Science             Female    210468467
#                          Male      213937594
#                          Other      10629160
# Electrical Engineering   Female     59435042
#                          Male       65823687
#                          Other       2393874
# Information Technology   Female    149885223
#                          Male      146887780
#                          Other       5522176
# Software Engineering     Female    280396934
#                          Male      286237969
#                          Other      12335534
# Name: Starting_Salary_USD, dtype: int64

# %%
# Find the total number of internships for each Major and Placement Mode combination
df.groupby(["Major", "Placement_Mode"])["Internships"].sum()
# Out:
# Major                    Placement_Mode
# Artificial Intelligence  campus placement         14287
#                          internship conversion     5680
#                          not applicable            3610
#                          off-campus                5755
#                          referral                  2825
# Business Analytics       campus placement          4822
#                          internship conversion     1798
#                          not applicable            5001
#                          off-campus                1870
#                          referral                   971
# Computer Science         campus placement         21147
#                          internship conversion     8126
#                          not applicable            8776
#                          off-campus                8455
#                          referral                  4090
# Cybersecurity            campus placement          8549
#                          internship conversion     3406
#                          not applicable            3400
#                          off-campus                3226
#                          referral                  1684
# Data Science             campus placement         10509
#                          internship conversion     3978
#                          not applicable            4081
#                          off-campus                4129
#                          referral                  2206
# Electrical Engineering   campus placement          2954
#                          internship conversion     1162
#                          not applicable            3048
#                          off-campus                1278
#                          referral                   663
# Information Technology   campus placement          6977
#                          internship conversion     2769
#                          not applicable            4630
#                          off-campus                3092
#                          referral                  1458
# Software Engineering     campus placement         14181
#                          internship conversion     5889
#                          not applicable            3674
#                          off-campus                5449
#                          referral                  2839
# Name: Internships, dtype: int64

# %%
# What is the total starting salary generated by Computer Science students?
df[df["Major"] == "Computer Science"]["Starting_Salary_USD"].sum()
# Out:
# np.int64(871751000)

# %%
# Calculate the total starting salary for each University Year, Major, and Gender combination
df.groupby(["University_Year", "Major", "Gender"])["Starting_Salary_USD"].sum()
# Out:
# University_Year  Major                    Gender
# Freshman         Artificial Intelligence  Female    55796752
#                                           Male      57902735
#                                           Other      2084893
#                  Business Analytics       Female    17925218
#                                           Male      17748416
#                                                       ...
# Sophomore        Information Technology   Male      33425873
#                                           Other      1909886
#                  Software Engineering     Female    70693959
#                                           Male      70700914
#                                           Other      3216574
# Name: Starting_Salary_USD, Length: 96, dtype: int64

# %%
# For each Major, calculate:
# Total Starting Salary
# Average Starting Salary
# Total Internships
# Average Employability Score

df.groupby("Major").agg(
    Total_Salary = ("Starting_Salary_USD", "sum"),
    Average_Salary = ("Starting_Salary_USD", "mean"),
    Total_Internships = ("Internships", "sum"),
    Average_Employability_Score = ("Employability_Score", "mean"))
# Out:
#                          Total_Salary  Average_Salary  Total_Internships  \
# Major
# Artificial Intelligence     582043660    77554.118588              32157
# Business Analytics          199443132    49526.479265              14462
# Computer Science            871751000    70262.835496              50594
# Cybersecurity               352217142    70797.415477              20265
# Data Science                435035221    71130.677077              24903
# Electrical Engineering      127652603    50099.137755               9105
# Information Technology      302295179    61617.443742              18926
# Software Engineering        578970437    77031.723922              32032
#
#                          Average_Employability_Score
# Major
# Artificial Intelligence                   226.633205
# Business Analytics                        189.869580
# Computer Science                          215.123430
# Cybersecurity                             215.120312
# Data Science                              214.964143
# Electrical Engineering                    189.432437
# Information Technology                    203.491256
# Software Engineering                      226.064409

# %%
# For each University Year, calculate:
# Total Starting Salary
# Average Starting Salary
# Total Students
# Average Internships

df.groupby("University_Year").agg(
    Total_Salary = ("Starting_Salary_USD", "sum"),
    Average_Salary = ("Starting_Salary_USD", "mean"),
    Total_Students = ("Student_ID", "count"),
    Average_Internships = ("Internships", "mean"))
# Out:
#                  Total_Salary  Average_Salary  Total_Students  \
# University_Year
# Freshman            689809979    70116.891543            9838
# Junior             1020771171    68646.346402           14870
# Senior              870445459    68766.429057           12658
# Sophomore           868381765    68733.715767           12634
#
#                  Average_Internships
# University_Year
# Freshman                    4.059158
# Junior                      4.058440
# Senior                      4.030337
# Sophomore                   4.048203

# %%
# For each Major and Placement Mode, calculate:
# Total Starting Salary
# Total Students
# Average Employability Score

df.groupby(["Major", "Placement_Mode"]).agg(
    Total_Salary = ("Starting_Salary_USD", "sum"),
    Total_Students = ("Student_ID", "count"),
    Average_Employability_Score = ("Employability_Score", "mean"))
# Out:
#                                                Total_Salary  Total_Students  \
# Major                   Placement_Mode
# Artificial Intelligence campus placement          291571704            3256
#                         internship conversion     114603804            1278
#                         not applicable                    0            1004
#                         off-campus                118267489            1321
#                         referral                   57600663             646
# Business Analytics      campus placement          101334422            1211
#                         internship conversion      38060647             453
#                         not applicable                    0            1649
#                         off-campus                 39183691             470
#                         referral                   20864372             244
# Computer Science        campus placement          442065877            4974
#                         internship conversion     168729754            1904
#                         not applicable                    0            2579
#                         off-campus                176297642            1992
#                         referral                   84657727             958
# Cybersecurity           campus placement          178351122            2010
#                         internship conversion      70667034             794
#                         not applicable                    0            1013
#                         off-campus                 67883536             760
#                         referral                   35315450             398
# Data Science            campus placement          218195559            2458
#                         internship conversion      84234009             945
#                         not applicable                    0            1221
#                         off-campus                 86094594             971
#                         referral                   46511059             521
# Electrical Engineering  campus placement           62659971             753
#                         internship conversion      24589812             293
#                         not applicable                    0            1014
#                         off-campus                 26778561             320
#                         referral                   13624259             168
# Information Technology  campus placement          148104361            1701
#                         internship conversion      58181532             670
#                         not applicable                    0            1444
#                         off-campus                 65261294             745
#                         referral                   30747992             346
# Software Engineering    campus placement          291644034            3256
#                         internship conversion     119506542            1337
#                         not applicable                    0            1036
#                         off-campus                110229140            1238
#                         referral                   57590721             649
#
#                                                Average_Employability_Score
# Major                   Placement_Mode
# Artificial Intelligence campus placement                        229.603256
#                         internship conversion                   230.795775
#                         not applicable                          206.873655
#                         off-campus                              229.336033
#                         referral                                228.611378
# Business Analytics      campus placement                        201.507845
#                         internship conversion                   201.609934
#                         not applicable                          173.255518
#                         off-campus                              200.762660
#                         referral                                201.609426
# Computer Science        campus placement                        220.458374
#                         internship conversion                   220.553624
#                         not applicable                          195.068127
#                         off-campus                              219.782279
#                         referral                                220.934603
# Cybersecurity           campus placement                        220.504080
#                         internship conversion                   220.252078
#                         not applicable                          194.203850
#                         off-campus                              220.783618
#                         referral                                220.115955
# Data Science            campus placement                        220.706672
#                         internship conversion                   219.499683
#                         not applicable                          193.085422
#                         off-campus                              220.504583
#                         referral                                220.593570
# Electrical Engineering  campus placement                        199.832470
#                         internship conversion                   201.672696
#                         not applicable                          173.071252
#                         off-campus                              200.721406
#                         referral                                198.719048
# Information Technology  campus placement                        210.675603
#                         internship conversion                   211.157388
#                         not applicable                          183.956337
#                         off-campus                              212.526510
#                         referral                                215.399566
# Software Engineering    campus placement                        229.348065
#                         internship conversion                   229.315557
#                         not applicable                          205.577027
#                         off-campus                              229.411874
#                         referral                                229.211402

# %%
# Which Major has the highest Total Starting Salary, and what is its Average Employability Score?
df.groupby("Major").agg(
    Total_Salary = ("Starting_Salary_USD", "sum"),
    Average_Employability_Score = ("Employability_Score", "mean")).sort_values("Total_Salary", ascending=False).head(1)
# Out:
#                   Total_Salary  Average_Employability_Score
# Major
# Computer Science     871751000                    215.12343

# %%
# Find the Top 5 Career Fields based on Total Starting Salary, and show their Average Employability Score as well

df.groupby("Career_Field").agg(
    Total_Salary = ("Starting_Salary_USD", "sum"),
    Avg_Employability_Score = ("Employability_Score", "mean")).sort_values("Total_Salary", ascending=False).head()
# Out:
#                    Total_Salary  Avg_Employability_Score
# Career_Field
# Software Engineer     581081160               224.408030
# Data Scientist        343210812               225.822185
# AI Engineer           338469705               225.421545
# Backend Developer     297878516               220.631518
# DevOps Engineer       288433738               229.496515

# %%
# Find the percentage of total students for each Placement Status

result = df.groupby("Placement_Status")["Student_ID"].agg(
    Count="count"
)

result["Percentage"] = result["Count"] * 100 / len(df)

result
# Out:
#                   Count  Percentage
# Placement_Status
# Not Placed        10960       21.92
# Placed            39040       78.08

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Revenue by Product Category

# %%
# Adapted: replaced "Product_Category" with "Major", "Revenue" with "Starting_Salary_USD"

category_salary = df.groupby("Major")["Starting_Salary_USD"].sum().sort_values(ascending=False)

plt.figure(figsize=(8, 5))
plt.bar(category_salary.index, category_salary.values, color="blue")

plt.xlabel("Major")
plt.ylabel("Total Starting Salary")
plt.title("Total Starting Salary by Major")

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Insight: Electronics generated the highest revenue among all product categories, significantly outperforming the other categories.

# %% [markdown]
# #  Orders by Payment Mode

# %%
# Adapted: replaced "Payment_Mode" with "Placement_Mode", "Order_ID" with "Student_ID"

mode = df.groupby("Placement_Mode")["Student_ID"].count()

plt.figure(figsize=(7, 7))
plt.pie(
    mode.values,
    labels=mode.index,
    autopct="%1.1f%%"
)

plt.title("Students by Placement Mode")
plt.show()

# %% [markdown]
# # insight - Net Banking is most preferred payment method among customer

# %% [markdown]
# # product vs avg_rating

# %%
# Adapted: replaced "Product" with "Major", "Rating" with "Employability_Score"

major_score = df.groupby("Major")["Employability_Score"].mean().sort_values(ascending=False)
plt.figure(figsize=(15, 5))
plt.bar(major_score.index, major_score.values, color="Green")
plt.xlabel("Major")
plt.ylabel("Avg_Employability_Score")
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# # Insight: T-shirts have the highest average rating among all products

# %% [markdown]
# # Monthly Revenue Trend

# %%
# Adapted: no date column exists in this dataset, so using University_Year
# (which has a natural order) instead of Order_Date, and Starting_Salary_USD instead of Revenue

year_order = ["Freshman", "Sophomore", "Junior", "Senior"]
yearly_salary = df.groupby("University_Year")["Starting_Salary_USD"].sum().reindex(year_order)

plt.figure(figsize=(10, 5))
plt.plot(yearly_salary.index.astype(str), yearly_salary.values, marker="o")

plt.xlabel("University Year")
plt.ylabel("Total Starting Salary")
plt.title("Total Starting Salary by University Year")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # insight - September recorded the highest monthly revenue, while October saw a sharp decline.

# %% [markdown]
# # Order Status Distribution

# %%
# Adapted: replaced "Order_Status" with "Placement_Status"

status = df["Placement_Status"].value_counts()

plt.figure(figsize=(7,7))

plt.pie(
    status.values,
    labels=status.index,
    autopct="%1.1f%%",
    wedgeprops={"width": 0.4}
)

plt.title("Placement Status Distribution")
plt.show()

# %% [markdown]
# # Insight: The majority of orders were successfully delivered (77.8%), indicating a strong order fulfillment rate, while returned and cancelled orders together accounted for 16.5%.
